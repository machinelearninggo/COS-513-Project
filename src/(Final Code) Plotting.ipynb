# %%
import matplotlib.pyplot as plt
import numpy as np

# Case 1

x = [1.0, 1.5848931924611136, 2.51188643150958, 3.9810717055349722, 6.309573444801933, 10.0, 15.848931924611133, 25.118864315095795, 39.810717055349734, 63.09573444801933, 100.0]
y = [0.6117693,  0.65681509, 0.70765075, 0.87765448, 0.92921423, 0.91572191, 0.87818151, 0.79541597, 0.75250532, 0.61145072, 0.57623287]

plt.figure(dpi=100)
plt.axes(xscale = "log")               
plt.plot(x,y)
plt.xlabel('lambda')
plt.ylabel('Average BAC over train data')

x = [0.1, 0.15848931924611134, 0.251188643150958, 0.3981071705534972, 0.6309573444801934, 1.0, 1.5848931924611134, 2.5118864315095797, 3.981071705534973, 6.309573444801933, 10.0]
y = [0.66765919, 0.77152927, 0.841481,   0.88022345, 0.93836111, 0.91156179, 0.81858833, 0.66932904 ,0.63096204, 0.59426478, 0.60041598]

plt.figure(dpi=100)
plt.axes(xscale = "log")               
plt.plot(x,y)
plt.xlabel('C')
plt.ylabel('Average BAC over train data')
# Out:
# Text(0, 0.5, 'Average BAC over train data')

# %%
# Case 2

x = [0.01, 0.0199526231496888, 0.039810717055349734, 0.07943282347242814, 0.15848931924611134, 0.31622776601683794, 0.6309573444801934, 1.2589254117941675, 2.5118864315095797, 5.011872336272725, 10.0]
y = [0.71724425, 0.72273699, 0.71856683, 0.72335228, 0.7253545 , 0.73029977, 0.74632452, 0.7630467 , 0.74703132, 0.68748307 ,0.57587993]

plt.figure(dpi=100)
plt.axes(xscale = "log")               
plt.plot(x,y)
plt.xlabel('lambda')
plt.ylabel('Average BAC over train data')

x = [0.1, 0.15848931924611134, 0.251188643150958, 0.3981071705534972, 0.6309573444801934, 1.0, 1.5848931924611134, 2.5118864315095797, 3.981071705534973, 6.309573444801933, 10.0]
y = [0.56798674, 0.66020953, 0.73514884, 0.76579816, 0.76737894 ,0.76191751 ,0.74617351, 0.73466324, 0.73124632 ,0.720952  , 0.72000868]

plt.figure(dpi=100)
plt.axes(xscale = "log")               
plt.plot(x,y)
plt.xlabel('C')
plt.ylabel('Average BAC over train data')
# Out:
# Text(0, 0.5, 'Average BAC over train data')
